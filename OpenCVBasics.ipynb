# %% [markdown]
# <a href="https://colab.research.google.com/github/yellomello/Python_Practice-Basics/blob/main/OpenCVBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
cb_img =cv2.imread("/content/dog.jpg",0)

# %%
print(cb_img)
# Out:
# [[ 41  43  45 ... 248 247 247]
#  [ 43  45  48 ... 247 247 247]
#  [ 47  48  51 ... 247 247 247]
#  ...
#  [129 129 130 ... 202 202 202]
#  [130 131 131 ... 203 203 203]
#  [131 132 132 ... 203 203 203]]

# %%
print("Image size is ", cb_img.shape)
# Out:
# Image size is  (480, 768)

# %%
plt.imshow(cb_img, cmap = 'gray')

# %%
coke_img =cv2.imread("coke.png",1)
print("Image size is", coke_img.shape)
print("Data type of image is", coke_img.dtype)
# Out:
# Image size is (763, 789, 3)
# Data type of image is uint8

# %%
plt.imshow(coke_img)

# %%
coke_img_channels_reversed = coke_img[:,:,::-1]

# %%
plt.imshow(coke_img_channels_reversed)

# %%
img_barrie_bgr = cv2.imread("lake_simcoe.png", cv2.IMREAD_COLOR)
b,g,r =cv2.split(img_barrie_bgr)

# %%
plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(r,cmap='gray'); plt.title("Red Channel")
plt.subplot(142);plt.imshow(g,cmap='gray'); plt.title("Green Channel")
plt.subplot(143);plt.imshow(b,cmap='gray'); plt.title("Blue Channel")
# Out:
# Text(0.5, 1.0, 'Blue Channel')

# %%
plt.figure(figsize=[20,5])
# plt.subplot(141);plt.imshow(r,cmap='gray'); plt.title("Red Channel")
plt.subplot(142);plt.imshow(g,cmap='gray'); plt.title("Green Channel")
# Out:
# Text(0.5, 1.0, 'Green Channel')

# %%
plt.figure(figsize=[20,5])
# Out:
# Text(0.5, 1.0, 'Blue Channel')

# %%
cv2.imwrite("lake_simcoe_bgr.png",img_barrie_bgr)
# Out:
# True

# %%
Image(filename='lake_simcoe_bgr.png')
