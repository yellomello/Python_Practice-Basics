# %% [markdown]
# <a href="https://colab.research.google.com/github/yellomello/Python_Practice-Basics/blob/main/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = [13, 43, 29, 11, 99, 37, 55, 17]

# %%
s[::2]
# Out:
# [13, 29, 99, 55]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s=[13,43,99,20,45]
k=3

# %%
#Solution:
from random import sample
sample(s,k)
# Out:
# [45, 99, 20]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a={}

# %%
for i in range(1,11):
  a[i]=i**3

# %%
a
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729, 10: 1000}

# %%
s=[13,43,99,20,45]
k=3
